# %%
import pandas as pd
df = pd.read_csv("./sample.csv")

# %%
from math import ceil

def get_check(code:str):
    check = 0
    multiplier = 1

    for ch in code[:-1]:
        check += int(ch) * multiplier
        multiplier = 3 if multiplier == 1 else 1
    
    return ceil(check / 10) * 10 - check


def is_valid_gtin(code):
    if type(code) == int:
        code = str(code)
    n = len(code)
    if n != 13 or not code.isnumeric():
        return False
    
    # India specific
    if code[:3] != "890":
        return False
    
    check = get_check(code)
    
    return  check == int(code[12])

# %%
correct = 0
for code in df["Product GTIN"]:
    score = gtin_score(code)
    if score == 0:
        print(code)
    correct += score

print(f"{correct} / {len(df)} {(correct / len(df) *100)}% valid")
# Out:
# 89008690
# 8886451002495
# 8886451084620
# 8886451084637
# 8006830910245
# 8006830910221
# 8006830910146
# 8006830910023
# 89000724
# 818601020675
# 818601020705
# 818601020699
# 818601020712
# 818601020729
# 818601020927
# 818601020934
# 818601020965
# 818601020538
# 818601020958
# 818601020545
# 818601020552
# 818601020569
# 818601020576
# 89000687
# 89006733
# 89006740
# 89007853
# 89007976
# 4792024016476
# 4792024001069
# 7039010528498
# 7039010528504
# 8886467100277
# 8886467106491
# 8886467106484
# 8886467108952
# 8886467109041
# 8886467112461
# 8886467120237
# 8886467120244
# 8886467106477
# 854646008001
# 854646008070
# 854646008087
# 854646008094
# 854646008117
# 854646008131
# 8410076600301
# 8410076600578
# 8410076600271
# 8410076700315
# 8852756054149
# 8852756054026
# 8852756517163
# 89008669
# 89008607
# 89008621
# 89008645
# 89008430
# 8000500239162
# 8000500239216
# 8000500239193
# 8000500328873
# 8000500342428
# 8000500342404
# 8000500341742
# 8000500342367
# 8000500342381
# 8000500342305
# 8000500342329
# 8000500328668
# 8000500348208
# 8000500360606
# 8000500362679
# 8000500362655
# 6909825011472
# 7622201098995
# 7622201137588
# 7622201137991
# 80824169
# 4897036692608
# 4792229616709
# 5902 / 5984 98.62967914438502% valid
